# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "meta-llama/Llama-3.2-1B-Instruct" # "dice-research/lola_v1" # "TucanoBR/Tucano-2b4" #"ricdomolm/lawma-8b" #"meta-llama/Llama-3.2-1B-Instruct" #
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

def testar_contexto(max_tokens):
    texto = "Palavra " * max_tokens  # texto simples, repetido
    inputs = tokenizer(texto, return_tensors="pt")
    try:
        outputs = model.generate(**inputs, max_new_tokens=5)
        print(f"✅ {max_tokens} tokens: aceito!")
    except Exception as e:
        print(f"❌ {max_tokens} tokens: falhou - {e}")

# Teste incremental

for tamanho in [512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144]:
    testar_contexto(tamanho)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ✅ 512 tokens: aceito!
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ✅ 1024 tokens: aceito!
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ✅ 2048 tokens: aceito!
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ✅ 4096 tokens: aceito!
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ✅ 8192 tokens: aceito!
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ✅ 16384 tokens: aceito!
# ✅ 32768 tokens: aceito!
# Token indices sequence length is longer than the specified maximum sequence length for this model (131074 > 131072). Running this sequence through the model will result in indexing errors
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
