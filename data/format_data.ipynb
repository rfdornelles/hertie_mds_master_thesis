# %%
## transform data from the original format to the format that can be used by the model

import os
import json
import pandas as pd
# Out:
# Running cells with '.venv (Python 3.10.14)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/228446@hertie-school.lan/workspace/master_thesis/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
